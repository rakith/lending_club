# %%
import pandas as pd

# %%
df=pd.read_csv('loan.csv',low_memory=False)

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=39717, step=1)

# %% [markdown]
# ### Print sum of all null values

# %%
#print(df['dti_joint'].isnull().sum())

# %% [markdown]
# ### Remove the repeated 'Cust_' from the column Cust_id so that the output column Cust_id have just numbers like 1, 2, 3 and so on.
#
# Print the first 10 rows of the dataset  'customer' after processing.
#
# -------------------------
# customer['Cust_id'] = customer['Cust_id'].str.replace("Cust_", "")
# print(customer.head(10))
#
# ----

# %% [markdown]
# ### Remove duplicate rows
#
# -----
#
#
# rating_update = rating.drop_duplicates()
# #Type your code here
#
# print(rating.shape)
#
# print(rating_update.shape)

# %%
df=df[df['loan_status']!='Current']

# %%
df.shape
# Out:
# (38577, 111)

# %%
df['int_rate']=pd.to_numeric(df['int_rate'].str.strip('%'))
# Out:
# C:\Users\rakit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 5      1075269    1311441       5000         5000           5000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term  int_rate  installment grade sub_grade  ...  \
# 0       36 months     10.65       162.87     B        B2  ...
# ...

# %%
df['emp_length']=df['emp_length'].str.replace('years','').str.replace('year','').str.replace('+','').str.replace('<','').str.replace('n/a','')
# Out:
# C:\Users\rakit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_strip = df['emp_length'].str.strip().unique()

# %%
df_strip
# Out:
# array(['10', '1', '3', '8', '9', '4', '5', '6', '2', '7', nan],
#       dtype=object)

# %%
df["emp_length"]=df["emp_length"].fillna(value=df['emp_length'].median())
# Out:
# C:\Users\rakit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df["emp_length"].unique()
# Out:
# array(['10 ', ' 1 ', '3 ', '8 ', '9 ', '4 ', '5 ', '1 ', '6 ', '2 ', '7 ',
#        4.0], dtype=object)

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
df_Fully_Paid = df[df['loan_status']=="Fully Paid"]

# %%
df_Fully_Paid
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 5      1075269    1311441       5000         5000           5000.0
# 6      1069639    1304742       7000         7000           7000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term  int_rate  installment grade sub_grade  ...  \
# 0       36 months     10.65       162.87     B        B2  ...
# ...

# %%
df_Fully_Paid["loan_status"]
# Out:
# 0        Fully Paid
# 2        Fully Paid
# 3        Fully Paid
# 5        Fully Paid
# 6        Fully Paid
#             ...
# 39712    Fully Paid
# 39713    Fully Paid
# 39714    Fully Paid
# 39715    Fully Paid
# 39716    Fully Paid
# Name: loan_status, Length: 32950, dtype: object

# %%
df.shape
# Out:
# (38577, 111)

# %%
df_Fully_Paid.shape
# Out:
# (32950, 111)

# %%
df[df['emp_length']==10].values_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-218-65665aad34c5> in <module>
# ----> 1 df[df['emp_length']==10].values_count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'values_count'

# %%
df['emp_length'].value_counts()
# Out:
# 10     8488
#  1     4508
# 2      4291
# 3      4012
# 4      3342
# 5      3194
# 1      3169
# 6      2168
# 7      1711
# 8      1435
# 9      1226
# 4.0    1033
# Name: emp_length, dtype: int64
